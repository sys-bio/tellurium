# %% [markdown]
# Back to the main [Index](../index.ipynb)

# %% [markdown]
# #### Stochastic simulation

# %%
# %matplotlib inline
from __future__ import print_function
import tellurium as te
import numpy as np

r = te.loada('S1 -> S2; k1*S1; k1 = 0.1; S1 = 40')
r.setIntegrator('gillespie')

results = []
for k in range(1, 20):
    r.reset()
    s = r.simulate(0, 40)
    results.append(s)
    r.plot(s, show=False, loc=None, color='black', alpha=0.7, linewidth=1.0)

# %%
# Setting the seed results in reproducible stochastic simulation
results = []
for k in range(1, 20):
    r.reset()
    r.setSeed(123456)
    s = r.simulate(0, 40)
    results.append(s)
    r.plot(s, show=False, loc=None, color='black', alpha=0.7, linewidth=1.0)

# %% [markdown]
# #### Run two simulations and combine the two

# %%
import tellurium as te
import numpy as np

r = te.loada('S1 -> S2; k1*S1; k1 = 0.1; S1 = 40')
result1 = r.gillespie (0, 100)
print(result1)

r.reset()
r.k1 = r.k1*20
result2 = r.gillespie (100, 200)


# Merge the two runs together
np.hstack([result1, result2])
# r.plot(np.vstack([result1, result2]))
# Out:
# array([[   0.,   40.,    0.,  100.,   40.,    0.],
#        [   2.,   34.,    6.,  102.,    0.,   40.],
#        [   4.,   31.,    9.,  104.,    0.,   40.],
#        [   6.,   25.,   15.,  106.,    0.,   40.],
#        [   8.,   20.,   20.,  108.,    0.,   40.],
#        [  10.,   15.,   25.,  110.,    0.,   40.],
#        [  12.,   13.,   27.,  112.,    0.,   40.],
#        [  14.,    8.,   32.,  114.,    0.,   40.],
#        [  16.,    6.,   34.,  116.,    0.,   40.],
#        [  18.,    4.,   36.,  118.,    0.,   40.],
#        [  20.,    3.,   37.,  120.,    0.,   40.],
#        [  22.,    2.,   38.,  122.,    0.,   40.],
#        [  24.,    1.,   39.,  124.,    0.,   40.],
#        [  26.,    0.,   40.,  126.,    0.,   40.],
#        [  28.,    0.,   40.,  128.,    0.,   40.],
#        [  30.,    0.,   40.,  130.,    0.,   40.],
#        [  32.,    0.,   40.,  132.,    0.,   40.],
#        [  34.,    0.,   40.,  134.,    0.,   40.],
#        [  36.,    0.,   40.,  136.,    0.,   40.],
#        [  38.,    0.,   40.,  138.,    0.,   40.],
#        [  40.,    0.,   40.,  140.,    0.,   40.],
#        [  42.,    0.,   40.,  142.,    0.,   40.],
#        [  44.,    0.,   40.,  144.,    0.,   40.],
#        [  46.,    0.,   40.,  146.,    0.,   40.],
#        [  48.,    0.,   40.,  148.,    0.,   40.],
#        [  50.,    0.,   40.,  150.,    0.,   40.],
#        [  52.,    0.,   40.,  152.,    0.,   40.],
#        [  54.,    0.,   40.,  154.,    0.,   40.],
#        [  56.,    0.,   40.,  156.,    0.,   40.],
#        [  58.,    0.,   40.,  158.,    0.,   40.],
#        [  60.,    0.,   40.,  160.,    0.,   40.],
#        [  62.,    0.,   40.,  162.,    0.,   40.],
#        [  64.,    0.,   40.,  164.,    0.,   40.],
#        [  66.,    0.,   40.,  166.,    0.,   40.],
#        [  68.,    0.,   40.,  168.,    0.,   40.],
#        [  70.,    0.,   40.,  170.,    0.,   40.],
#        [  72.,    0.,   40.,  172.,    0.,   40.],
#        [  74.,    0.,   40.,  174.,    0.,   40.],
#        [  76.,    0.,   40.,  176.,    0.,   40.],
#        [  78.,    0.,   40.,  178.,    0.,   40.],
#        [  80.,    0.,   40.,  180.,    0.,   40.],
#        [  82.,    0.,   40.,  182.,    0.,   40.],
#        [  84.,    0.,   40.,  184.,    0.,   40.],
#        [  86.,    0.,   40.,  186.,    0.,   40.],
#        [  88.,    0.,   40.,  188.,    0.,   40.],
#        [  90.,    0.,   40.,  190.,    0.,   40.],
#        [  92.,    0.,   40.,  192.,    0.,   40.],
#        [  94.,    0.,   40.,  194.,    0.,   40.],
#        [  96.,    0.,   40.,  196.,    0.,   40.],
#        [  98.,    0.,   40.,  198.,    0.,   40.],
#        [ 100.,    0.,   40.,  200.,    0.,   40.]])
