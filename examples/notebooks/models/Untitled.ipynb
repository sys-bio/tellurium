# %%
import tellurium as te
import tellurium.tests.test_runner as test_runner
runner = test_runner.TestRunner()
runner.run_all()
# Out:
# test_1Model1PhrasedML (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Minimal example which should work. ... ok
# test_1Model2PhrasedML (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Test multiple models and multiple phrasedml files. ... /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1550: UserWarning: More than one sedml file in archive, only processing first one.
#   warnings.warn("More than one sedml file in archive, only processing first one.")
# /home/mkoenig/git/tellurium/tellurium/sedml/tephrasedml.py:213: UserWarning: No phrasedml string selected, defaulting to first phrasedml.
#   warnings.warn("No phrasedml string selected, defaulting to first phrasedml.")
# ok
# test_2Model1PhrasedML (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Test multiple models and multiple phrasedml files. ... ok
# test_2Model2PhrasedML (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Test multiple models and multiple phrasedml files. ... ok
# test_ModelAsPath (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Provide model as path. ... ok
# test_ModelAsURN (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Provide model via urn. ... ok
# test_createpython (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Test createpython. ... ok
# test_execute (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Test execute. ... ok
# test_experiment (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Test experiment. ... ok
# test_exportAsCombine (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Test exportAsCombine. ... ok
# test_kisao_absolute_tolerance_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# ['tellurium.tests.test_tephrasedml', 'tellurium.tests.test_tesedml', 'tellurium.tests.test_examples', 'tellurium.tests.test_tellurium', 'tellurium.tests.test_tecombine', 'tellurium.tests.test_API', 'tellurium.tests.test_analysis', 'tellurium.tests.test_io', 'tellurium.tests.test_runner']
# uniformTimeCourse
# ok
# test_kisao_absolute_tolerance_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpZ_oCbZ_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpZ_oCbZ_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('absolute_tolerance', 1e-08)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_adams (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpZ7GQxs_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpZ7GQxs_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('absolute_tolerance', 1e-08)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpciqMjz_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpciqMjz_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('stiff', False)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
# ok
# test_kisao_bdf (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpuL5LLy_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpuL5LLy_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('stiff', True)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
# ok
# test_kisao_cvode_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ... ok
# test_kisao_cvode_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ... ok
# test_kisao_cvode_3 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Default of uniform is cvode. ... ok
# test_kisao_cvode_4 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Default of onestep is cvode. ... ok
# test_kisao_gillespie_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ... ok
# test_kisao_gillespie_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ... ok
# test_kisao_gillespie_3 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase)
# Default of uniform_stochastic is gillespie. ... ok
# test_kisao_initial_time_step_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# uniformTimeCourse
# ok
# test_kisao_initial_time_step_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpa65jto_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpa65jto_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('initial_time_step', 0.01)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_maximum_adams_order_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpcKA5AG_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpcKA5AG_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('initial_time_step', 0.01)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_maximum_adams_order_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpg0LhnQ_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpg0LhnQ_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('maximum_adams_order', 5)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_maximum_bdf_order_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmprU93jn_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmprU93jn_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('maximum_adams_order', 5)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_maximum_bdf_order_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpMZcVZ7_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpMZcVZ7_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('maximum_bdf_order', 4)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_maximum_iterations_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpjJsK0g_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpjJsK0g_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('maximum_bdf_order', 4)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# steadyState
# ok
# test_kisao_maximum_iterations_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpOvORnq_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpOvORnq_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setSteadyStateSolver('nleq')
# model0.steadyStateSolver.setValue('maximum_iterations', 10)
# model0.conservedMoietyAnalysis = True
# model0.steadyStateSelections = ['S1', 'time']
# model0.simulate()
# task0[0] = model0.steadyState()
# model0.conservedMoietyAnalysis = False
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# steadyState
# ok
# test_kisao_maximum_num_steps_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmposqcsM_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmposqcsM_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setSteadyStateSolver('nleq')
# model0.steadyStateSolver.setValue('maximum_iterations', 10)
# model0.conservedMoietyAnalysis = True
# model0.steadyStateSelections = ['S1', 'time']
# model0.simulate()
# task0[0] = model0.steadyState()
# model0.conservedMoietyAnalysis = False
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_maximum_num_steps_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpKyHoxD_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpKyHoxD_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('maximum_num_steps', 10000)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_maximum_time_step_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpoIMhe__sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpoIMhe__sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('maximum_num_steps', 10000)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_maximum_time_step_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmp6U89xA_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmp6U89xA_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('maximum_time_step', 1.0)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# uniformTimeCourse
# ok
# test_kisao_minimum_damping_1 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpkGxSAj_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpkGxSAj_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setIntegrator('cvode')
# model0.integrator.setValue('maximum_time_step', 1.0)
# model0.timeCourseSelections = ['S1', 'time']
# task0[0] = model0.simulate(start=0.0, end=10.0, steps=100)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8)
# plt.title('plot_0', fontweight='bold')
# plt.xlabel('task0.time', fontweight='bold')
# plt.ylabel('task0.S1', fontweight='bold')
# __lg = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# __lg.draw_frame(False)
# plt.setp(__lg.get_texts(), fontsize='small')
# plt.setp(__lg.get_texts(), fontweight='bold')
# plt.savefig(os.path.join(workingDir, 'plot_0.png'), dpi=100)
# plt.show()
#
#
# steadyState
# ok
# test_kisao_minimum_damping_2 (tellurium.tests.test_tephrasedml.tePhrasedMLTestCase) ...
# """
#     tellurium 1.3.1
#
#     auto-generated code
#     sedmlDoc: L1V2
#     workingDir: /tmp/tmpakDcvs_sedml/_te_m1
#     inputType: COMBINE_FILE
# """
# from __future__ import print_function, division
# import tellurium as te
# from tellurium.sedml.mathml import *
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# import libsedml
# import pandas
# import os.path
#
# workingDir = '/tmp/tmpakDcvs_sedml/_te_m1'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model0>
# model0 = te.loadSBMLModel(os.path.join(workingDir, 'm1.xml'))
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <task0>
# # Task: <task0>
# task0 = [None]
# model0.setSteadyStateSolver('nleq')
# model0.steadyStateSolver.setValue('minimum_damping', 1.0)
# model0.conservedMoietyAnalysis = True
# model0.steadyStateSelections = ['S1', 'time']
# model0.simulate()
# task0[0] = model0.steadyState()
# model0.conservedMoietyAnalysis = False
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <plot_0_0_0>
# __var__task0_____time = np.transpose(np.array([sim['time'] for sim in task0]))
# if len(__var__task0_____time.shape) == 1:
#      __var__task0_____time.shape += (1,)
# plot_0_0_0 = __var__task0_____time
#
# # DataGenerator <plot_0_0_1>
# __var__task0_____S1 = np.transpose(np.array([sim['S1'] for sim in task0]))
# if len(__var__task0_____S1.shape) == 1:
#      __var__task0_____S1.shape += (1,)
# plot_0_0_1 = __var__task0_____S1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot_0>
# plt.figure(num=None, figsize=(9, 5), dpi=80, facecolor='w', edgecolor='k')
# from matplotlib import gridspec
# __gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
# plt.subplot(__gs[0])
# for k in range(plot_0_0_0.shape[1]):
#     if k == 0:
#         plt.plot(plot_0_0_0[:,k], plot_0_0_1[:,k], '-o', color='r', linewidth=1.5, markersize=3.0, alpha=0.8, label='task0.S1')
#     else:
# ...
#       <parameter id="k1" value="1" constant="true"/>
#     </listOfParameters>
#     <listOfReactions>
#       <reaction id="_J0" reversible="true" fast="false">
#         <listOfReactants>
#           <speciesReference species="S1" stoichiometry="1" constant="true"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="S2" stoichiometry="1" constant="true"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> k1 </ci>
#               <ci> S1 </ci>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#     </listOfReactions>
#   </model>
# </sbml>
#
# // Created by libAntimony v2.9
# model *myModel()
#
#   // Compartments and Species:
#   species S1, S2;
#
#   // Reactions:
#   _J0: S1 -> S2; k1*S1;
#
#   // Species initializations:
#   S1 = 10;
#   S2 = 0;
#
#   // Variable initializations:
#   k1 = 1;
#
#   // Other declarations:
#   const k1;
# end
# ok
# test_getsedml (tellurium.tests.test_tecombine.teCombineTestCase)
# Test getSEDML. ... ok
# test_getsedmlaspharsedml (tellurium.tests.test_tecombine.teCombineTestCase)
# Test getSEDMLAsPhrasedml. ...
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- Created by phraSED-ML version v1.0.1 on 2016-03-09 13:34 with libSBML version 5.12.1. -->
# <sedML xmlns="http://sed-ml.org/sed-ml/level1/version2" level="1" version="2">
#   <listOfSimulations>
#     <uniformTimeCourse id="sim1" initialTime="0" outputStartTime="0" outputEndTime="5" numberOfPoints="100">
#       <algorithm kisaoID="KISAO:0000019"/>
#     </uniformTimeCourse>
#   </listOfSimulations>
#   <listOfModels>
#     <model id="model1" language="urn:sedml:language:sbml.level-3.version-1" source="myModel"/>
#   </listOfModels>
#   <listOfTasks>
#     <task id="task1" modelReference="model1" simulationReference="sim1"/>
#   </listOfTasks>
#   <listOfDataGenerators>
#     <dataGenerator id="plot_0_0_0" name="time">
#       <listOfVariables>
#         <variable id="time" symbol="urn:sedml:symbol:time" taskReference="task1"/>
#       </listOfVariables>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <ci> time </ci>
#       </math>
#     </dataGenerator>
#     <dataGenerator id="plot_0_0_1" name="S1">
#       <listOfVariables>
#         <variable id="S1" target="/sbml:sbml/sbml:model/descendant::*[@id='S1']" taskReference="task1" modelReference="model1"/>
#       </listOfVariables>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <ci> S1 </ci>
#       </math>
#     </dataGenerator>
#     <dataGenerator id="plot_0_1_1" name="S2">
#       <listOfVariables>
#         <variable id="S2" target="/sbml:sbml/sbml:model/descendant::*[@id='S2']" taskReference="task1" modelReference="model1"/>
#       </listOfVariables>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <ci> S2 </ci>
#       </math>
#     </dataGenerator>
#   </listOfDataGenerators>
#   <listOfOutputs>
#     <plot2D id="plot_0" name="Figure 1">
#       <listOfCurves>
#         <curve logX="false" logY="false" xDataReference="plot_0_0_0" yDataReference="plot_0_0_1"/>
#         <curve logX="false" logY="false" xDataReference="plot_0_0_0" yDataReference="plot_0_1_1"/>
#       </listOfCurves>
#     </plot2D>
#   </listOfOutputs>
# </sedML>
#
# // Created by libphrasedml v1.0.1
# // Models
# model1 = model "myModel"
#
# // Simulations
# sim1 = simulate uniform(0, 5, 100)
#
# // Tasks
# task1 = run sim1 on model1
#
# // Outputs
# plot "Figure 1" time vs S1, S2
# ok
# test_listcontents (tellurium.tests.test_tecombine.teCombineTestCase)
# Test listContents. ... ok
# test_listdetailedcontents (tellurium.tests.test_tecombine.teCombineTestCase)
# Test listDetailedContents. ...
# ['myModel.xml', 'experiment1.xml', 'manifest.xml']
# [{'type': 'sbml', 'filename': 'myModel.xml'}, {'modelsource': [], 'type': 'sedml', 'filename': 'experiment1.xml'}]
# ok
# test_readmanifest (tellurium.tests.test_tecombine.teCombineTestCase)
# Test readManifest. ... ok
# test_api000_te_getVersionInfo (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api001_te_printVersionInfo (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api002_te_getTelluriumVersion (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api003_te_noticesOff (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api004_te_noticesOn (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api005_te_saveToFile (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api006_te_readFromFile (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api007_te_loada (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api008_te_loadAntimonyModel (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api009_te_loads (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api010_te_loadSBMLModel (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api011_te_loadCellMLModel (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api012_te_antimonyToSBML (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api013_te_antimonyToCellML (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api014_te_sbmlToAntimony (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api015_te_sbmlToCellML (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api016_te_cellmlToAntimony (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api017_te_cellmlToSBML (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api018_te_experiment (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api019_te_getEigenvalues (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api020_te_plotArray (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api021_te_loadTestModel (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api022_te_getTestModel (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api023_te_listTestModels (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api024_te_LatexExport (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api025_te_ParameterScan (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api026_te_SteadyStateScan (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api027_r_getAntimony (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api028_r_getCurrentAntimony (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api029_r_getCellML (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api030_r_getCurrentCellML (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api031_r_getMatlab (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api032_r_getCurrentMatlab (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api033_r_exportToAntimony (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api034_r_exportToCellML (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api035_r_exportToMatlab (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api036_r_resetToOrigin (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api037_r_resetAll (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api038_r_getRatesOfChange (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api039_r_draw (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api040_r_plot (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api041_r_getSeed (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api042_r_setSeed (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api043_r_gillespie (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api044_r_fjac (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api045_r_sm (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api046_r_rs (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api047_r_fs (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api048_r_bs (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api049_r_ps (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api050_r_vs (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api051_r_dv (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api052_r_rv (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api053_r_sv (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api054_r_getBoundarySpeciesConcentrations (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api055_r_getBoundarySpeciesIds (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api056_r_getNumBoundarySpecies (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api057_r_getFloatingSpeciesConcentrations (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api058_r_getFloatingSpeciesIds (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api059_r_getNumFloatingSpecies (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api060_r_getGlobalParameterIds (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api061_r_getGlobalParameterValues (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api062_r_getNumGlobalParameters (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api063_r_getCompartmentIds (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api064_r_getCompartmentVolumes (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api065_r_getNumCompartments (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api066_r_getConservedMoietyValues (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api067_r_getNumConservedMoieties (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api068_r_getNumDepFloatingSpecies (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api069_r_getNumIndFloatingSpecies (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api070_r_getReactionIds (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api071_r_getReactionRates (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api072_r_getNumReactions (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api073_r_getNumEvents (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_api074_r_getNumRateRules (tellurium.tests.test_API.APITestCase)
# Test fails if class or function is not callable under the given name str. ... ok
# test_plot2DParameterScan (tellurium.tests.test_analysis.MyTestCase)
# Test plot2DParameterScan. ... ok
# test_latex_export (tellurium.tests.test_io.ExportTestCase)
# Test latex export. ...
# [{'type': 'sbml', 'filename': 'myModel.xml'}, {'modelsource': [], 'type': 'sedml', 'filename': 'experiment1.xml'}]
# writing data document: /tmp/tmpDZEZ8B/Model_data1.txt
# ok
# test_latex_export2 (tellurium.tests.test_io.ExportTestCase)
# Test latex export. ...
# writing data document: /tmp/tmpDZEZ8B/Model_data2.txt
# writing latex document: /tmp/tmpDZEZ8B/Model_code.tex
# writing data document: /tmp/tmpDZEZ8B/Model_data1.txt
# writing data document: /tmp/tmpDZEZ8B/Model_data2.txt
# writing latex document: /tmp/tmpDZEZ8B/Model_code.tex
# writing latex document: /tmp/tmppMAXLG/Model.txt
# ok
#
# ----------------------------------------------------------------------
# Ran 277 tests in 78.353s
#
# OK (expected failures=2)
# <unittest.runner.TextTestResult run=277 errors=0 failures=0>

# %%
r = te.loada("""
J0: S1 -> S2; k1*S1
S1=10; S2=0; k1=0.2
""")
s = r.simulate()
r.plot()
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc'>
