# %%
# %matplotlib inline

# %%
from __future__ import print_function
import tellurium as te
import phrasedml.phrasedml as phrasedml

antimonyStr = """
model test
    J0: S1 -> S2; k1*S1;
    S1 = 10.0; S2=0.0;
    k1 = 0.1;
end
"""
phrasedmlStr = """
    model0 = model "test"
    model1 = model "test" with S1=5.0, k1=0.3
    sim0 = simulate uniform(0, 10, 100)
    sim1 = simulate uniform_stochastic(0, 10, 100)
    task0 = run sim0 on model0
    task1 = run sim1 on model1
    plot task0.time vs task0.S1, task0.S2, task1.S1, task1.S2
"""

r = te.loada(antimonyStr)
sbmlStr = r.getSBML()
phrasedml.setReferencedSBML("test", sbmlStr)
sedml = phrasedml.convertString(phrasedmlStr)

exp = te.experiment(antimonyStr, phrasedmlStr)
exp.execute()

# %%
import roadrunner
roadrunner.RoadRunner("urn:miriam:biomodels.db:BIOMD0000000003.xml")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-af4911e12686> in <module>()
#       1 import roadrunner
# ----> 2 roadrunner.RoadRunner("urn:miriam:biomodels.db:BIOMD0000000003.xml")
#
# /home/mkoenig/git/tellurium/tellurium/tellurium.pyc in __init__(self, *args, **kwargs)
#     459
#     460     def __init__(self, *args, **kwargs):
# --> 461         super(ExtendedRoadRunner, self).__init__(*args, **kwargs)
#     462
#     463     # ---------------------------------------------------------------------
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in _new_init(self, *args)
#    2639
#    2640     def _new_init(self, *args):
# -> 2641         RoadRunner._swig_init(self, *args)
#    2642         RoadRunner._makeProperties(self)
#    2643
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in __init__(self, *args)
#    1886     __getattr__ = lambda self, name: _swig_getattr(self, RoadRunner, name)
#    1887     def __init__(self, *args):
# -> 1888         this = _roadrunner.new_RoadRunner(*args)
#    1889         try: self.this.append(this)
#    1890         except: self.this = this
#
# RuntimeError: static std::string rr::SBMLReader::read(const string&), could not open urn:miriam:biomodels.db:BIOMD0000000003.xml as a file or uri

# %%
import matplotlib

# %%
matplotlib.rcParams['axes.color_cycle']
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# [u'b', u'g', u'r', u'c', u'm', u'y', u'k']

# %%
5%3
# Out:
# 2
