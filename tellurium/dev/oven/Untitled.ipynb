# %%
import tellurium as te
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
dgs = te.executeCombineArchive("L1V3_vanderpol-sbml.omex", printPython=True)
# Out:
# """
# ####################################################################################################
#                             tellurium 2.0.2
# -+++++++++++++++++-         Python Environment for Modeling and Simulating Biological Systems
#  .+++++++++++++++.
#   .+++++++++++++.           Homepage: http://tellurium.analogmachine.org/
# -//++++++++++++/.   -:/-`   Documentation: https://tellurium.readthedocs.io/en/latest/index.html
# .----:+++++++/.++  .++++/   Forum: https://groups.google.com/forum/#!forum/tellurium-discuss
#       :+++++:  .+:` .--++   Bug reports: https://github.com/sys-bio/tellurium/issues
#        -+++-    ./+:-://.   Repository: https://github.com/sys-bio/tellurium
#         .+.       `...`
#
# SED-ML simulation experiments: http://www.sed-ml.org/
#     sedmlDoc: L1V3
#     workingDir: '/tmp/tmp9ussyr_t'
#     inputType: SEDML_FILE
#
# Linux-4.10.0-35-generic-x86_64-with-Ubuntu-16.04-xenial
# python 3.6.2 (default, Jul 20 2017, 08:43:29)
# [GCC 5.4.1 20170519]
# ####################################################################################################
# """
# import tellurium as te
# from roadrunner import Config
# from tellurium.sedml.mathml import *
# from tellurium.sedml.tesedml import process_trace, terminate_trace, fix_endpoints
#
# import numpy as np
# import matplotlib.pyplot as plt
# import mpl_toolkits.mplot3d
# try:
#     import tesedml as libsedml
# except ImportError:
#     import libsedml
# import pandas
# import os.path
# Config.LOADSBMLOPTIONS_RECOMPILE = True
#
# workingDir = r'/tmp/tmp9ussyr_t'
#
# # --------------------------------------------------------
# # Models
# # --------------------------------------------------------
# # Model <model>
# model = te.loadSBMLModel(os.path.join(workingDir, 'vanderpol-sbml.xml'))
#
#
#
# # --------------------------------------------------------
# # Tasks
# # --------------------------------------------------------
# # Task <repeatedTask>
#
# repeatedTask = []
# __range__once = [1.0]
# for __k__once, __value__once in enumerate(__range__once):
#     model.reset()
#     # Task: <task1>
#     task1 = [None]
#     model.setIntegrator('cvode')
#     model.integrator.setValue('absolute_tolerance', 1e-07)
#     model.integrator.setValue('maximum_num_steps', 500)
#     model.integrator.setValue('maximum_time_step', 0.0)
#     model.integrator.setValue('relative_tolerance', 1e-07)
#     if model.conservedMoietyAnalysis == True: model.conservedMoietyAnalysis = False
#     model.timeCourseSelections = ['[x]', '[y]', 'time']
#     model.reset()
#     task1[0] = model.simulate(start=0.0, end=100.0, steps=1000)
#
#     repeatedTask.extend(task1)
# # Task <task1>
# # Task: <task1>
# task1 = [None]
# model.setIntegrator('cvode')
# model.integrator.setValue('absolute_tolerance', 1e-07)
# model.integrator.setValue('maximum_num_steps', 500)
# model.integrator.setValue('maximum_time_step', 0.0)
# model.integrator.setValue('relative_tolerance', 1e-07)
# if model.conservedMoietyAnalysis == True: model.conservedMoietyAnalysis = False
# model.timeCourseSelections = ['time']
# model.reset()
# task1[0] = model.simulate(start=0.0, end=100.0, steps=1000)
#
# # --------------------------------------------------------
# # DataGenerators
# # --------------------------------------------------------
# # DataGenerator <xDataGenerator1_1>
# __var__xVariable1_1 = np.concatenate([process_trace(sim['time']) for sim in task1])
# if len(__var__xVariable1_1.shape) == 1:
#      __var__xVariable1_1.shape += (1,)
# xDataGenerator1_1 = __var__xVariable1_1
# # DataGenerator <yDataGenerator1_1>
# __var__yVariable1_1 = np.concatenate([process_trace(sim['[x]']) for sim in repeatedTask])
# if len(__var__yVariable1_1.shape) == 1:
#      __var__yVariable1_1.shape += (1,)
# yDataGenerator1_1 = __var__yVariable1_1
# # DataGenerator <xDataGenerator2_1>
# __var__xVariable2_1 = np.concatenate([process_trace(sim['time']) for sim in task1])
# if len(__var__xVariable2_1.shape) == 1:
#      __var__xVariable2_1.shape += (1,)
# xDataGenerator2_1 = __var__xVariable2_1
# # DataGenerator <yDataGenerator2_1>
# __var__yVariable2_1 = np.concatenate([process_trace(sim['[y]']) for sim in repeatedTask])
# if len(__var__yVariable2_1.shape) == 1:
#      __var__yVariable2_1.shape += (1,)
# yDataGenerator2_1 = __var__yVariable2_1
# # DataGenerator <xDataGenerator3_1>
# __var__xVariable3_1 = np.concatenate([process_trace(sim['[x]']) for sim in repeatedTask])
# if len(__var__xVariable3_1.shape) == 1:
#      __var__xVariable3_1.shape += (1,)
# xDataGenerator3_1 = __var__xVariable3_1
# # DataGenerator <yDataGenerator3_1>
# __var__yVariable3_1 = np.concatenate([process_trace(sim['[y]']) for sim in repeatedTask])
# if len(__var__yVariable3_1.shape) == 1:
#      __var__yVariable3_1.shape += (1,)
# yDataGenerator3_1 = __var__yVariable3_1
#
# # --------------------------------------------------------
# # Outputs
# # --------------------------------------------------------
# # Output <plot1>
# stacked=False
# if not stacked:
#     fig = te.getPlottingEngine().newFigure(title='plot1')
# else:
#     fig = te.getPlottingEngine().newStackedFigure(title='plot1')
# for k in range(xDataGenerator1_1.shape[1]):
#     if k == 0:
#         extra_args = {'name': 'yDataGenerator1_1'}
#     else:
#         extra_args = {{}}
#     fig.addXYDataset(xDataGenerator1_1[:,k], yDataGenerator1_1[:,k], color='C0', tag='tag0', **extra_args)
#     fix_endpoints(xDataGenerator1_1[:,k], yDataGenerator1_1[:,k], color='C0', tag='tag0', fig=fig)
# for k in range(xDataGenerator2_1.shape[1]):
#     if k == 0:
#         extra_args = {'name': 'yDataGenerator2_1'}
#     else:
#         extra_args = {{}}
#     fig.addXYDataset(xDataGenerator2_1[:,k], yDataGenerator2_1[:,k], color='C1', tag='tag1', **extra_args)
#     fix_endpoints(xDataGenerator2_1[:,k], yDataGenerator2_1[:,k], color='C1', tag='tag1', fig=fig)
# fig.render()
# # Output <plot2>
# stacked=False
# if not stacked:
#     fig = te.getPlottingEngine().newFigure(title='plot2')
# else:
#     fig = te.getPlottingEngine().newStackedFigure(title='plot2')
# for k in range(xDataGenerator3_1.shape[1]):
#     if k == 0:
#         extra_args = {'name': 'yDataGenerator3_1'}
#     else:
#         extra_args = {{}}
#     fig.addXYDataset(xDataGenerator3_1[:,k], yDataGenerator3_1[:,k], color='C0', tag='tag0', **extra_args)
#     fix_endpoints(xDataGenerator3_1[:,k], yDataGenerator3_1[:,k], color='C0', tag='tag0', fig=fig)
# fig.render()
# ####################################################################################################
# /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1706: UserWarning:
#
# line 102: (01015 [Error]) Missing a required XML attribute. The plot2D attribute 'logX' is required.
#
# line 102: (01015 [Error]) Missing a required XML attribute. The plot2D attribute 'logY' is required.
#
# line 102: (01015 [Error]) Missing a required XML attribute. The plot2D attribute 'logX' is required.
#
# line 102: (01015 [Error]) Missing a required XML attribute. The plot2D attribute 'logY' is required.
#
#
#
# /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1251: UserWarning:
#
# Unsupported AlgorithmParameter: KISAO:0000475 = BDF)
#
# /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1251: UserWarning:
#
# Unsupported AlgorithmParameter: KISAO:0000481 = true)
#
# /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1251: UserWarning:
#
# Unsupported AlgorithmParameter: KISAO:0000476 = Newton)
#
# /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1251: UserWarning:
#
# Unsupported AlgorithmParameter: KISAO:0000477 = Dense)
#
# /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1251: UserWarning:
#
# Unsupported AlgorithmParameter: KISAO:0000480 = 0)
#
# /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1251: UserWarning:
#
# Unsupported AlgorithmParameter: KISAO:0000478 = Banded)
#
# /home/mkoenig/git/tellurium/tellurium/sedml/tesedml.py:1251: UserWarning:
#
# Unsupported AlgorithmParameter: KISAO:0000479 = 0)
# <div id="cb7c5dfc-abf4-45d3-8171-6eb9446d3680" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cb7c5dfc-abf4-45d3-8171-6eb9446d3680", [{"type": "scatter", "x": [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6000000000000001, 0.7000000000000001, 0.8, 0.9, 1.0, 1.1, 1.2000000000000002, 1.3, 1.4000000000000001, 1.5, 1.6, 1.7000000000000002, 1.8, 1.9000000000000001, 2.0, 2.1, 2.2, 2.3000000000000003, 2.4000000000000004, 2.5, 2.6, 2.7, 2.8000000000000003, 2.9000000000000004, 3.0, 3.1, 3.2, 3.3000000000000003, 3.4000000000000004, 3.5, 3.6, 3.7, 3.8000000000000003, 3.9000000000000004, 4.0, 4.1000000000000005, 4.2, 4.3, 4.4, 4.5, 4.6000000000000005, 4.7, 4.800000000000001, 4.9, 5.0, 5.1000000000000005, 5.2, 5.300000000000001, 5.4, 5.5, 5.6000000000000005, 5.7, 5.800000000000001, 5.9, 6.0, 6.1000000000000005, 6.2, 6.300000000000001, 6.4, 6.5, 6.6000000000000005, 6.7, 6.800000000000001, 6.9, 7.0, 7.1000000000000005, 7.2, 7.300000000000001, 7.4, 7.5, 7.6000000000000005, 7.7, 7.800000000000001, 7.9, 8.0, 8.1, 8.200000000000001, 8.3, 8.4, 8.5, 8.6, 8.700000000000001, 8.8, 8.9, 9.0, 9.1, 9.200000000000001, 9.3, 9.4, 9.5, 9.600000000000001, 9.700000000000001, 9.8, 9.9, 10.0, 10.100000000000001, 10.200000000000001, 10.3, 10.4, 10.5, 10.600000000000001, 10.700000000000001, 10.8, 10.9, 11.0, 11.100000000000001, 11.200000000000001, 11.3, 11.4, 11.5, 11.600000000000001, 11.700000000000001, 11.8, 11.9, 12.0, 12.100000000000001, 12.200000000000001, 12.3, 12.4, 12.5, 12.600000000000001, 12.700000000000001, 12.8, 12.9, 
473064590886175, 1.9919319080818734, 2.0079410615699347, 2.00246435413708, 1.9811127712870489, 1.947979269147109, 1.9059043701003067, 1.8567838802701035, 1.8018303521049441, 1.7417690147354419, 1.6769728706451243, 1.607551606532734, 1.533407268085834, 1.4542643248354103, 1.3696819861979588, 1.2790523254639772, 1.1815871547846786, 1.0762956769985517, 0.9619553650233157, 0.8370806614367526, 0.6998988875743741, 0.5483525833059539, 0.38016624168260715, 0.1930418174901916, -0.014912102785917716, -0.2443889743650704, -0.4936519208855423, -0.7570304211940108, -1.0238510585793155, -1.2790318505937333, -1.5062224662368076, -1.6925408338892123, -1.8321296464684167, -1.9264202955646563, -1.9816548528545024, -2.0057974483010796, -2.0063677744908084, -1.989476891586583, -1.9596724077050653, -1.9201539838859387, -1.8730824268389714, -1.8198603934885083, -1.7613484609862977, -1.6980182504826895, -1.6300547257732023, -1.5574208142017019, -1.4798947105680855, -1.3970871924338635, -1.308444010984852, -1.2132358742276124, -1.1105388300214138, -0.9992069876291714, -0.8778411247661164, -0.7447608824960515, -0.5979956123333271, -0.4353254625928614, -0.25442654465516684, -0.05321291567175889, 0.16950024460241514, 0.4129027049420879, 0.6727256291298424, 0.939919926818581, 1.2005826093024783, 1.4382827545747856, 1.6385386429159707, 1.7930704087901947, 1.9011799141435533, 1.9679353772587125, 2.001050268005315, 2.0083412307712107, 1.9964104422027191, 1.9702870961799908, 1.9335647378133178, 1.8886998641336439, 1.8373083656498261, 1.7804029686548963, 1.7185651436146883, 1.6520619966462349, 1.5809215415421212, 1.504977714157136, 1.4238933726631346, 1.3371670028606626, 1.2441264330679922, 1.143911924363248, 1.0354511263321458, 0.9174283680818871, 0.7882545484497216, 0.6460496909440728, 0.4886634363763063, 0.31377945584778844, 0.11918272538050692, -0.09669330336181142, -0.3338151804659951, -0.5891751169121231, -0.85533118552733, -1.1197934981049407, -1.366519134597287, -1.5798754798545338, -1.7492997385907243, -1.8717647147940322, -1.9508363333953809, -1.993718336294104, -2.0083954574896916, -2.0019286255253026, -1.9798450636987321, -1.9461633679399775, -1.9036658610581925, -1.854205518948137, -1.7989643947799123, -1.73864543471331, -1.6736053646195441, -1.6039417470596926, -1.5295465306980562, -1.4501353084524888, -1.3652586757985385, -1.2742998600054025, -1.1764608225484225, -1.0707396341083784, -0.9559010755828701, -0.8304453942256641, -0.6925849698950991, -0.5402488420091631, -0.37115411368617823, -0.1830104225075294, 0.026035597768116085, 0.2565874720790301, 0.5067451887429669, 0.7706016572668725, 1.0372254425961314, 1.2913727936938035, 1.5167520070239715, 1.7007745685692277, 1.8379767738965322, 1.9301084414956442, 1.9835699025109763, 2.0063443383370054, 2.0058943775564053, 1.9882508025730825, 1.9578860365190442, 1.9179395134735369, 1.8705272817922292, 1.8170198495474046, 1.7582548425150275, 1.6946872326035218, 1.6264894238246554, 1.5536142633831005, 1.4758311791795915, 1.3927426314499876, 1.3 ...

# %%
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-20df7bd33167> in <module>()
# ----> 1 fig
#
# NameError: name 'fig' is not defined

# %%
import plotly.plotly as py
import plotly.graph_objs as go

py.sign_in('DemoAccount', '2qdyfjyr7o') # Replace the username, and API key with your credentials.

trace = go.Bar(x=[2, 4, 6], y= [10, 12, 15])
data = [trace]
layout = go.Layout(title='A Simple Plot', width=800, height=640)
fig = go.Figure(data=data, layout=layout)

py.image.save_as(fig, filename='a-simple-plot.png')

from IPython.display import Image
Image('a-simple-plot.png')
